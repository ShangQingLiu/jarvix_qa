# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
import faiss
# dimensions of text-ada-embedding-002
d = 1536 
faiss_index = faiss.IndexFlatL2(d)

# %%
from llama_index import SimpleDirectoryReader, load_index_from_storage, GPTVectorStoreIndex, StorageContext
from llama_index.vector_stores.faiss import FaissVectorStore
from IPython.display import Markdown, display
import os
import openai

# %%
# os.environ['OPENAI_API_KEY'] = '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'
os.environ['OPENAI_API_KEY'] = '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'

# %%
# load documents
upload_files =[]
path = "../mount_storage/uploads/SMT Expert/"
for r,d,f in os.walk(path):
    for file in f:
        upload_files.append(os.path.join(r,file))

# %%
documents = SimpleDirectoryReader("",upload_files).load_data()
print(documents)
# Out:
# [Document(text='SMT\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\tPubIİshing House of Electronics Industry dË\t• BEIJING\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n¡ $ș\n\n¡q ¡pȚ ş[¡\n\n\tÿĘ .....................................•.•.\t• •. • •.  •• • ••. •• • • • • •• • •• • • • - • • • • •• • • • • • • • • • • • • • • • • • • • • -\n\n109\n\n1 36\n\n.’   Țq\n\n\t\tțȚ\t.. . . . . , .. .. . . . . . . . . • •\t• . . • . • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • • •\n\nI ] 0\n\n1 37\n\nGB\n\nJ@ . .. ... ... ... ... ... .........•.• •. . . •. . •. •• • •• • • • • •• • •• • • • • • • • • • • • • • •• • •• • • • • • • • • • • • •• • • •\n\n11 1\n\n1 gig\n\n.@•jjj Țğțÿ\n\n\t[șj\t• • • • •. • • •• • •• • • • • • • • • • •• • • • • • • • • • • •
# ...

# %%
vector_store = FaissVectorStore(faiss_index=faiss_index)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
index = GPTVectorStoreIndex.from_documents(documents, storage_context=storage_context)
# Out:
# INFO:llama_index.token_counter.token_counter:> [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [build_index_from_nodes] Total embedding token usage: 149029 tokens
# > [build_index_from_nodes] Total embedding token usage: 149029 tokens
# > [build_index_from_nodes] Total embedding token usage: 149029 tokens

# %%
# save index to disk
index.storage_context.persist()

# %%
# load index from disk
vector_store = FaissVectorStore.from_persist_dir('./storage')
storage_context = StorageContext.from_defaults(vector_store=vector_store, persist_dir="./storage")
index = load_index_from_storage(storage_context=storage_context)
# Out:
# INFO:root:Loading llama_index.vector_stores.faiss from ./storage/vector_store.json.
# Loading llama_index.vector_stores.faiss from ./storage/vector_store.json.
# INFO:llama_index.indices.loading:Loading all indices.
# Loading all indices.

# %%
# set Logging to DEBUG for more detailed outputs
query_engine = index.as_query_engine()
response = query_engine.query("What is advantage of using SMT? answer in Chinese")
# Out:
# INFO:llama_index.token_counter.token_counter:> [retrieve] Total LLM token usage: 0 tokens
# > [retrieve] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [retrieve] Total embedding token usage: 11 tokens
# > [retrieve] Total embedding token usage: 11 tokens
# INFO:llama_index.token_counter.token_counter:> [get_response] Total LLM token usage: 2322 tokens
# > [get_response] Total LLM token usage: 2322 tokens
# INFO:llama_index.token_counter.token_counter:> [get_response] Total embedding token usage: 0 tokens
# > [get_response] Total embedding token usage: 0 tokens

# %%
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>
# SMT技术的优势包括：（1）体积小得多，一般可减小60%～70%，甚至可减小90%；重量减轻60%～90%；（2）信号传输速度高；（3）高频特性好；（4）有利于自动化生产，提高成品率和生产效率；（5）材料成本低；（6）SMT技术简化了电子整机产品的生产工序</b>

# %%
# set Logging to DEBUG for more detailed outputs
query_engine = index.as_query_engine()
response = query_engine.query("List all the special things in SMT")
# Out:
# INFO:llama_index.token_counter.token_counter:> [retrieve] Total LLM token usage: 0 tokens
# > [retrieve] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [retrieve] Total embedding token usage: 8 tokens
# > [retrieve] Total embedding token usage: 8 tokens
# INFO:llama_index.token_counter.token_counter:> [get_response] Total LLM token usage: 1864 tokens
# > [get_response] Total LLM token usage: 1864 tokens
# INFO:llama_index.token_counter.token_counter:> [get_response] Total embedding token usage: 0 tokens
# > [get_response] Total embedding token usage: 0 tokens

# %%
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>
# 1. SMT components are much smaller than traditional components.
# 2. SMT components are directly soldered onto the PCB without drilling holes.
# 3. SMT technology enables high density, high reliability, miniaturization, low cost, and automation of production.
# 4. SMT process includes assembly materials, assembly process design, assembly technology, and assembly equipment.
# 5. SMT process can be single-sided surface assembly, double-sided surface assembly, single-sided through-hole assembly, and double-sided through-hole assembly.
# 6. SMT process reduces the number of soldering times.</b>
